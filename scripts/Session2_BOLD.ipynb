# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns




data=np.load('BOLD_image.npy', allow_pickle=True)

type(data)
data.shape
# Out:
# (63, 74, 62)

# %%
data.shape

image=data[:,:,40]

plt.imshow(image, cmap='gray')

plt.axhline(y=30, color='r', linestyle='--')
plt.axvline(x=40, color='r', linestyle='--')

# %%
plt.plot(data[40,30,:])

# %%
plt.plot(data[:,30,40])
ax=plt.gca()

# %%
data=np.load('BOLD_movie.npy', allow_pickle=True)

type(data)
data.shape
# Out:
# (63, 74, 62, 10)

# %%
fig = plt.figure(figsize=(20, 2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(data[:,:,40,i], cmap='gray')
    
plt.tight_layout()

# %%
plt.plot(data[40,30,40,:])
