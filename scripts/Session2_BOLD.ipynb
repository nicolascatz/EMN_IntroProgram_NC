# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# Revenir automatiquement à la racine du projet (dossier parent de "scripts")
if os.path.basename(os.getcwd()) == "scripts":
    os.chdir("..")




data=np.load('data/BOLD_image.npy', allow_pickle=True)


data.shape
# Out:
# (63, 74, 62)

# %%
## BOLD Signal Analysis

# the structure of the data is a 3D array with dimensions (x axis, y axis, slice)

# get the image 40 (in depth slice 40)
image1=data[:,:,40] #  image 40

plt.imshow(image1, cmap='gray')
